# %%
import random

from fastlite import database

db = database("lithuanian_data.db")

# Grab references to your tables
numbers = db.t["numbers"]
attempts = db.t["attempts"]

# %%
all_nums = list(numbers.rows)   # returns a list of dicts
row = random.choice(all_nums)


price = f"€{row['number']}"


price
# Out:
# '€25'

# %%
row
# Out:
# {'number': 25,
#  'neoficialiai': 'dvidešimt',
#  'compound': 'penki',
#  'years': 'metai',
#  'kokia_kaina': 'dvidešimt',
#  'kokia_kaina_compound': 'penki',
#  'euro_nom': 'eurai',
#  'cent_nom': 'centai',
#  'kiek_kainuoja': 'dvidešimt',
#  'kiek_kainuoja_compound': 'penkis',
#  'euro_acc': 'eurus',
#  'cent_acc': 'centus'}
